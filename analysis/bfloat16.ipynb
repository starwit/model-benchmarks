# %%
from common import *

# %%
files = [
    '../remote_bfloat16/metrics_yolov8n_b1_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b2_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b4_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b8_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b16_cpu_48t.csv',
    '../results/amx_verification/metrics_yolov8n_b24_cpu_48c_bf16.csv',
    '../remote_bfloat16/metrics_yolov8n_b32_cpu_48t.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'bfloat16', 'total_per_frame').show()

# %%
files = [
    '../results/bfloat16/metrics_yolov8n_b4_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b4_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b8_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b8_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b12_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b12_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b16_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b16_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b20_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b20_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b24_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b24_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b28_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b28_cpu_48t_bf16.csv',
    '../results/bfloat16/metrics_yolov8n_b32_cpu_48t.csv',
    '../results/bfloat16/metrics_yolov8n_b32_cpu_48t_bf16.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'bfloat16', 'fps').show()
