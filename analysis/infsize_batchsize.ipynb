# %%
from common import *

# %%
files = [
    '../results/infsize_batchsize/metrics_yolov8n_b1_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b2_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b4_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b8_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b16_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b32_cpu_48t_s640.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b64_cpu_48t_s640.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Inference size 640x640', 'fps').show()

files = [
    '../results/infsize_batchsize/metrics_yolov8n_b1_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b2_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b4_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b8_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b16_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b32_cpu_48t_s1280.csv',
    '../results/infsize_batchsize/metrics_yolov8n_b64_cpu_48t_s1280.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Inference size 1280x1280', 'fps').show()
