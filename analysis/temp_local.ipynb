# %%
from common import *

# %%
files = [
    '../results/temp_local/metrics_yolov8n_b1_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b2_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b4_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b8_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b16_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b32_cuda.csv',
    '../results/temp_local/metrics_yolov8n_b64_cuda.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'GPU - Batchsizes - 640px', 'fps').show()

files = [
    '../results/temp_local/metrics_yolov8n_b1_cuda_1280.csv',
    '../results/temp_local/metrics_yolov8n_b2_cuda_1280.csv',
    '../results/temp_local/metrics_yolov8n_b4_cuda_1280.csv',
    '../results/temp_local/metrics_yolov8n_b8_cuda_1280.csv',
    '../results/temp_local/metrics_yolov8n_b16_cuda_1280.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'GPU - Batchsizes - 1280px', 'fps').show()

# %%
files = [
    '../results/temp_local/metrics_yolov8n_b1_cpu_noipex.csv',
    '../results/temp_local/metrics_yolov8n_b1_cpu_ipex.csv',
    '../results/temp_local/metrics_yolov8n_b2_cpu_noipex.csv',
    '../results/temp_local/metrics_yolov8n_b2_cpu_ipex.csv',
    '../results/temp_local/metrics_yolov8n_b4_cpu_noipex.csv',
    '../results/temp_local/metrics_yolov8n_b4_cpu_ipex.csv',
    '../results/temp_local/metrics_yolov8n_b8_cpu_noipex.csv',
    '../results/temp_local/metrics_yolov8n_b8_cpu_ipex.csv',
    '../results/temp_local/metrics_yolov8n_b16_cpu_noipex.csv',
    '../results/temp_local/metrics_yolov8n_b16_cpu_ipex.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'CPU - IPex', 'fps').show()
