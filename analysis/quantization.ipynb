# %%
from common import *

# %%
bfloat16_files = [
    '../remote_bfloat16/metrics_yolov8n_b1_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b2_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b4_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b8_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b16_cpu_48t.csv',
    '../remote_bfloat16/metrics_yolov8n_b32_cpu_48t.csv',
]

create_histograms([read_metrics(f) for f in bfloat16_files], bfloat16_files, 'BFloat16 - 48c/48t', 'fps').show()
create_histograms([read_metrics(f) for f in bfloat16_files], bfloat16_files, 'BFloat16 - 48c/48t', 'total_per_frame').show()

float32_files = [
    '../remote_single/metrics_yolov8n_b1_cpu_48t.csv',
    '../remote_single/metrics_yolov8n_b2_cpu_48t.csv',
    '../remote_single/metrics_yolov8n_b4_cpu_48t.csv',
    '../remote_single/metrics_yolov8n_b8_cpu_48t.csv',
    '../remote_single/metrics_yolov8n_b16_cpu_48t.csv',
    '../remote_single/metrics_yolov8n_b32_cpu_48t.csv',
]

create_histograms([read_metrics(f) for f in float32_files], float32_files, 'Float32 - 48c/48t', 'fps').show()
create_histograms([read_metrics(f) for f in float32_files], float32_files, 'Float32 - 48c/48t', 'total_per_frame').show()
