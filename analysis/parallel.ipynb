# %%
from common import *

# %%
files = [
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_4p_cpu0.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_4p_cpu14.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_4p_cpu56.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_4p_cpu70.csv',
]

create_histograms([read_metrics(f) for f in files], files, '14t/14c * 4', 'fps').show()

files = [
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu0.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu14.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu28.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu42.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu56.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu70.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu84.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_14c_8p_cpu98.csv',
]

create_histograms([read_metrics(f) for f in files], files, '14t/14c * 8', 'fps').show()

# %%
files = [
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_2p_cpu0.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_2p_cpu56.csv',
]

create_histograms([read_metrics(f) for f in files], files, '28t/28c * 2', 'fps').show()

files = [
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_4p_cpu0.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_4p_cpu28.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_4p_cpu56.csv',
    '../results/parallel/metrics_yolov8n_b8_cpu_28c_4p_cpu84.csv',
]

create_histograms([read_metrics(f) for f in files], files, '28t/28c * 4', 'fps').show()
