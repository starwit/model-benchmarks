# %%
from common import *

# %%
files = [
    '../results/threads_batchsize/metrics_yolov8n_b1_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b2_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b4_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b8_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b16_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b32_cpu_12t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b64_cpu_12t.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Batchsize @ 12t/12c', 'fps').show()

files = [
    '../results/threads_batchsize/metrics_yolov8n_b1_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b2_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b4_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b8_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b16_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b32_cpu_24t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b64_cpu_24t.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Batchsize @ 24t/24c', 'fps').show()

files = [
    '../results/threads_batchsize/metrics_yolov8n_b1_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b2_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b4_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b8_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b16_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b32_cpu_36t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b64_cpu_36t.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Batchsize @ 36t/36c', 'fps').show()

files = [
    '../results/threads_batchsize/metrics_yolov8n_b1_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b2_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b4_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b8_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b16_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b32_cpu_48t.csv',
    '../results/threads_batchsize/metrics_yolov8n_b64_cpu_48t.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Batchsize @ 48t/48c', 'fps').show()
