# %%
from common import *

# %%
files = [
    '../results/hyperthreading_batchsize/metrics_yolov8n_b1_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b2_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b4_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b16_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b32_cpu_24t24c.csv',
]

create_histograms([read_metrics(f) for f in files], files, '24t24c', 'fps').show()

# %%
files = [
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_6t6c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_12t6c.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Hyperthreading @ 6c', 'fps').show()

files = [
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_12t12c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_24t12c.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Hyperthreading @ 12c', 'fps').show()

files = [
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_24t24c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_48t24c.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Hyperthreading @ 24c', 'fps').show()

files = [
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_48t48c.csv',
    '../results/hyperthreading_batchsize/metrics_yolov8n_b8_cpu_96t48c.csv',
]

create_histograms([read_metrics(f) for f in files], files, 'Hyperthreading @ 48c', 'fps').show()
